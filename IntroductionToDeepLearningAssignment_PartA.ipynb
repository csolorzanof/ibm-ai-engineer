# %% [markdown]
# # Part A

# %%
#Install necessary libraries
# !pip install tensorflow_cpu==2.18
# !pip install pandas
# !pip install scikit-learn
# Out:
# Requirement already satisfied: tensorflow_cpu==2.18 in /opt/conda/lib/python3.11/site-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (3.4.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (5.29.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (2.31.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (3.7.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow_cpu==2.18) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow_cpu==2.18) (0.43.0)
# Requirement already satisfied: rich in /opt/conda/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow_cpu==2.18) (13.9.4)
# Requirement already satisfied: namex in /opt/conda/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow_cpu==2.18) (0.0.8)
# Requirement already satisfied: optree in /opt/conda/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow_cpu==2.18) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow_cpu==2.18) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow_cpu==2.18) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow_cpu==2.18) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow_cpu==2.18) (0.1.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.11/site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (3.5.0)

# %%
#import keras
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
# Out:
# 2024-12-06 22:39:51.647970: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-06 22:39:51.650237: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-06 22:39:51.654417: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-06 22:39:51.665502: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733524791.689546   54148 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733524791.695141   54148 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-06 22:39:51.726723: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#download the data
concrete_df = pd.read_csv('https://cocl.us/concrete_data')
concrete_df.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# ## Split the Data

# %%
#1. Randomly split the data into training and test sets
concrete_data_columns = concrete_df.columns
predictors = concrete_df[concrete_data_columns[concrete_data_columns != 'Strength']]
target = concrete_df['Strength']

# %%
#verify predictors
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
#verify target
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %%
#create the training and testing sets
train_X, test_X, train_y, test_y = train_test_split(predictors, target, test_size=0.3, random_state=10)

# %%
#verify the sets
print('train_X: {}'.format(train_X.shape))
print('train_y: {}'.format(train_y.shape))
print('test_X: {}'.format(test_X.shape))
print('test_y: {}'.format(test_y.shape))
# Out:
# train_X: (721, 8)
# train_y: (721,)
# test_X: (309, 8)
# test_y: (309,)

# %% [markdown]
# ## Create the model and train it

# %%
#2. Train the model on the training data using 50 epochs
n_cols = predictors.shape[1]
model = Sequential()
model.add(Input(shape=(n_cols,)))
model.add(Dense(10,activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(train_X, train_y,epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 23/23 - 1s - 29ms/step - loss: 62884.2344
# Epoch 2/50
# 23/23 - 0s - 6ms/step - loss: 22181.8223
# Epoch 3/50
# 23/23 - 0s - 5ms/step - loss: 6927.2295
# Epoch 4/50
# 23/23 - 0s - 6ms/step - loss: 3461.6963
# Epoch 5/50
# 23/23 - 0s - 5ms/step - loss: 2858.5896
# Epoch 6/50
# 23/23 - 0s - 4ms/step - loss: 2418.1040
# Epoch 7/50
# 23/23 - 0s - 4ms/step - loss: 1762.3634
# Epoch 8/50
# 23/23 - 0s - 4ms/step - loss: 1265.3369
# Epoch 9/50
# 23/23 - 0s - 4ms/step - loss: 943.3269
# Epoch 10/50
# 23/23 - 0s - 5ms/step - loss: 719.0146
# Epoch 11/50
# 23/23 - 0s - 5ms/step - loss: 564.9835
# Epoch 12/50
# 23/23 - 0s - 4ms/step - loss: 458.6951
# Epoch 13/50
# 23/23 - 0s - 4ms/step - loss: 379.9297
# Epoch 14/50
# 23/23 - 0s - 4ms/step - loss: 320.1114
# Epoch 15/50
# 23/23 - 0s - 4ms/step - loss: 279.5493
# Epoch 16/50
# 23/23 - 0s - 4ms/step - loss: 243.1850
# Epoch 17/50
# 23/23 - 0s - 4ms/step - loss: 218.3431
# Epoch 18/50
# 23/23 - 0s - 4ms/step - loss: 196.0288
# Epoch 19/50
# 23/23 - 0s - 4ms/step - loss: 180.6982
# Epoch 20/50
# 23/23 - 0s - 4ms/step - loss: 167.3605
# Epoch 21/50
# 23/23 - 0s - 4ms/step - loss: 155.1449
# Epoch 22/50
# 23/23 - 0s - 4ms/step - loss: 148.4137
# Epoch 23/50
# 23/23 - 0s - 4ms/step - loss: 141.8055
# Epoch 24/50
# 23/23 - 0s - 4ms/step - loss: 136.3183
# Epoch 25/50
# 23/23 - 0s - 4ms/step - loss: 131.4857
# Epoch 26/50
# 23/23 - 0s - 4ms/step - loss: 128.5140
# Epoch 27/50
# 23/23 - 0s - 4ms/step - loss: 125.4238
# Epoch 28/50
# 23/23 - 0s - 4ms/step - loss: 123.6128
# Epoch 29/50
# 23/23 - 0s - 4ms/step - loss: 120.5032
# Epoch 30/50
# 23/23 - 0s - 4ms/step - loss: 119.0111
# Epoch 31/50
# 23/23 - 0s - 4ms/step - loss: 119.6672
# Epoch 32/50
# 23/23 - 0s - 5ms/step - loss: 116.0953
# Epoch 33/50
# 23/23 - 0s - 4ms/step - loss: 115.7449
# Epoch 34/50
# 23/23 - 0s - 4ms/step - loss: 114.6392
# Epoch 35/50
# 23/23 - 0s - 4ms/step - loss: 114.5856
# Epoch 36/50
# 23/23 - 0s - 4ms/step - loss: 113.9957
# Epoch 37/50
# 23/23 - 0s - 4ms/step - loss: 113.0658
# Epoch 38/50
# 23/23 - 0s - 5ms/step - loss: 114.9896
# Epoch 39/50
# 23/23 - 0s - 4ms/step - loss: 112.5414
# Epoch 40/50
# 23/23 - 0s - 4ms/step - loss: 112.7382
# Epoch 41/50
# 23/23 - 0s - 4ms/step - loss: 112.0816
# Epoch 42/50
# 23/23 - 0s - 4ms/step - loss: 111.8738
# Epoch 43/50
# 23/23 - 0s - 4ms/step - loss: 112.3194
# Epoch 44/50
# 23/23 - 0s - 4ms/step - loss: 111.1540
# Epoch 45/50
# 23/23 - 0s - 4ms/step - loss: 111.6617
# Epoch 46/50
# 23/23 - 0s - 4ms/step - loss: 110.7893
# Epoch 47/50
# 23/23 - 0s - 4ms/step - loss: 111.3460
# Epoch 48/50
# 23/23 - 0s - 4ms/step - loss: 110.3640
# Epoch 49/50
# 23/23 - 0s - 4ms/step - loss: 110.7712
# Epoch 50/50
# 23/23 - 0s - 4ms/step - loss: 112.4969

# %%
#3. Evaluate the model on the test data and compute the MSE
predictions = model.predict(test_X)
loss = mean_squared_error(test_y, predictions)
print('MSE is {}'.format(loss))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE is 99.71182114920147

# %%
#4. Repeat Steps 1-3, 50 times and create a list of 50 mean squared errors
mse_errors = []
for x in range(0,50):
    print('On iteration {}'.format(x+1))
    train_X, test_X, train_y, test_y = train_test_split(predictors, target, test_size=0.3, random_state=10)
    model.fit(train_X, train_y,epochs=50, verbose=0)
    predictions = model.predict(test_X)
    loss = mean_squared_error(test_y, predictions)
    mse_errors.append(loss)
print('List of MSE: {}'.format(mse_errors))
# Out:
# On iteration 1
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 2
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 3
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# On iteration 5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# On iteration 6
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 7
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 8
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# On iteration 9
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 11
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 12
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 13
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 14
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 16
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 17
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 18
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 19
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# On iteration 21
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 22
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 23
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 24
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# On iteration 26
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 27
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 28
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 29
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 31
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 32
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 33
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 34
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# On iteration 36
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 38
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# On iteration 39
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# On iteration 40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 41
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 42
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 43
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# On iteration 44
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 46
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# On iteration 47
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 48
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 49
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# On iteration 50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# List of MSE: [np.float64(94.45346788318521), np.float64(68.30240883736438), np.float64(56.59017156770781), np.float64(54.8471620715542), np.float64(50.16319438092598), np.float64(57.44258323394071), np.float64(46.85863408210415), np.float64(47.141324008933644), np.float64(47.026661911457275), np.float64(45.213675097348876), np.float64(59.37679982734679), np.float64(44.2942077609394), np.float64(45.19731242282479), np.float64(47.590114061492585), np.float64(51.92824714029079), np.float64(45.03326304879464), np.float64(44.6717799968324), np.float64(45.9936481203613), np.float64(44.71654098133908), np.float64(44.4661200107391), np.float64(46.36397112556473), np.float64(44.53458208909556), np.float64(47.82296428809418), np.float64(44.098420754696434), np.float64(57.534510921631956), np.float64(45.96069753601177), np.float64(44.51014068936703), np.float64(46.17651766297059), np.float64(44.13779645875202), np.float64(45.7687230218936), np.float64(43.96587055813227), np.float64(50.73585701089581), np.float64(44.041640628192454), np.float64(43.78993351213295), np.float64(65.60773156526774), np.float64(44.42886500062299), np.float64(45.50449336155193), np.float64(48.61207159618231), np.float64(48.939726379992784), np.float64(43.08309169761803), np.float64(51.45773736008835), np.float64(41.9320442204301), np.float64(42.2188544413653), np.float64(44.466343037113134), np.float64(42.38637823385039), np.float64(41.2448450947124), np.float64(43.43803808237589), np.float64(41.717035650422446), np.float64(41.498722197197864), np.float64(42.41490952741637)]

# %%
#5. Reporting the mean and standard deviation of MSE list
mse_series = pd.Series(mse_errors)
print('Mean for the MSE: {}'.format(round(mse_series.mean(),4)))
print('Standard deviation for the MSE: {}'.format(round(mse_series.std(),4)))
# Out:
# Mean for the MSE: 48.394
# Standard deviation for the MSE: 8.8974
